# %% [markdown]
# # Ejercicios Pair Programming - Módulo 2 Sprint 2
# ## Lección 4 - LimpiezaIV
# ### Natalia García Lago y Noemi Azorín

# %%
import pandas as pd
import numpy as np
import sidetable as stb 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# En este caso trabajaremos con el dataframe que limpiamos en el ejercicio de pair de Limpieza anterior, el de Limpieza III, donde limpiabamos las columnas de species, age, etc. y eliminabamos los outliers.
#
# Antes de seguir, recordamos las preguntas que nos planteamos al principio del pair programming de EDA para dirigir nuestro análisis.
#
#
# - ¿Es Australia es el sitio más peligroso y letal para estar relajada en la playa?
#
#
# - ¿Cuál es el rango de edad que sufre la mayoría de los ataques?
#
#
# - Independientemente de la edad, sufren los hombres más ataques que las mujeres?
#
#
# - ¿En qué mes ocurren más ataques?
#
#
# - ¿Cuál es la relación entre la especie y el tipo de ataque (si es fatal o no)?
#
#
# - ¿Cómo han evolucionado los ataques a lo largo del tiempo?
#
#
# De todo esto, nos damos cuenta que solo tenemos que limpiar algunas de las columnas, en concreto age, species, country, fatal, year, sex. Si reducimos esto a una tabla para saber que tenemos ya limpito y que no. **Actualizamos esta tabla ya que en el ejercicio de pair de Limpieza I ya dejamos algunas columnas limpitas:

# %% [markdown]
# Es el momento de ponernos a trabajar con los valores nulos 💪🏽. A lo largo de este ejercicio de pair programming vamos a intentar eliminar los valores nulos de nuestras columnas. En la lección hemos aprendido varios métodos, nosotras os planteamos los ejercicios pero sentiros libres de usar el método que más se adapte a vuestras necesidades. Manos a la obra!

# %%
ataques = pd.read_csv("../ficheros/ataques_limpiezaIII.csv", index_col = 0 )
ataques.head(1)
# Out:
#   case_number  year     type country  activity age     species_  mes fatal  \
# 0  2018.06.25  2018  Boating     usa  Paddling  57  White shark  Jun     N
#
#   sex        especies  edad
# 0   F  Tiburón Blanco    57

# %% [markdown]
# 1. Lo primero que tenemos que evaluar es en que columnas tenemos nulos y que cantidad tenemos en cada una. ¿Hay alguna columna con una gran cantidad de nulos? En caso de que sea así deberemos eliminarla.

# %%
#Utilizamos el método missing de la librería sidetable para visualizar tanto el total de nulos como este en porcentaje.
nulos = ataques.stb.missing()

# %% [markdown]
# 2. Es el momento de eliminar los nulos:
#
#
# - Reemplazad los valores nulos de la columna age por la media de la edad, redondeada a dos decimales.
#
#
# - En relación a la columna de country al tratarse de una columna de tipo categórica, reemplazad los valores nulos por una nueva categória que se llame Unknown.
#
#
# - Reemplazad los valores nulos de la columna fatal por Unknown.
#
#
# - Reemplazad los valores nulos de la columna type por el valor más frecuente (la moda).
#
#
# - Reemplazad los valores nulos de la columna fecha por Unknown.

# %%
#Reemplazo de la columna age por media de edad con dos decimales 
# Sacamos la media de la columna edad.
media_edad = ataques["edad"].mean().round(2)

# %%
# Realizamos el reemplazo y comprobamos que se han realizado los cambios y nuestro porcentaje de nulos es 0.
ataques["age"].replace(np.nan, media_edad, inplace = True)
ataques.stb.missing()
# Out:
#              missing  total    percent
# mes              218   1672  13.038278
# species_         126   1672   7.535885
# especies         126   1672   7.535885
# fatal             97   1672   5.801435
# activity          31   1672   1.854067
# sex               15   1672   0.897129
# country           10   1672   0.598086
# case_number        0   1672   0.000000
# year               0   1672   0.000000
# type               0   1672   0.000000
# age                0   1672   0.000000
# edad               0   1672   0.000000

# %%
# Reemplazar nulos en columna Country por una nueva categoría "Unknown"
ataques["country"].replace(np.nan, "Unknown", inplace = True)
ataques.stb.missing()
# Out:
#              missing  total    percent
# mes              218   1672  13.038278
# species_         126   1672   7.535885
# especies         126   1672   7.535885
# fatal             97   1672   5.801435
# activity          31   1672   1.854067
# sex               15   1672   0.897129
# case_number        0   1672   0.000000
# year               0   1672   0.000000
# type               0   1672   0.000000
# country            0   1672   0.000000
# age                0   1672   0.000000
# edad               0   1672   0.000000

# %%
# Reemplazo de nulos en columna fatal por "Unknown"
ataques["fatal"].replace(np.nan, "Unknown", inplace = True)
ataques.stb.missing()
# Out:
#              missing  total    percent
# mes              218   1672  13.038278
# species_         126   1672   7.535885
# especies         126   1672   7.535885
# activity          31   1672   1.854067
# sex               15   1672   0.897129
# case_number        0   1672   0.000000
# year               0   1672   0.000000
# type               0   1672   0.000000
# country            0   1672   0.000000
# age                0   1672   0.000000
# fatal              0   1672   0.000000
# edad               0   1672   0.000000

# %%
# Reemplazo de los nulos de la columna type por la moda
# moda_type = ataques["type"].mode()
# ataques["type"].replace(np.nan, moda_type, inplace = True)

# %% [markdown]
# - Intentamos realizar el reemplazo de nulos pero resulta que contenía 0 nulos

# %%
# Reemplazo de los nulos de la columna mes por Unknown 
ataques["mes"].replace(np.nan, "Unknown", inplace = True)
ataques.stb.missing()
# Out:
#              missing  total   percent
# species_         126   1672  7.535885
# especies         126   1672  7.535885
# activity          31   1672  1.854067
# sex               15   1672  0.897129
# case_number        0   1672  0.000000
# year               0   1672  0.000000
# type               0   1672  0.000000
# country            0   1672  0.000000
# age                0   1672  0.000000
# mes                0   1672  0.000000
# fatal              0   1672  0.000000
# edad               0   1672  0.000000

# %%
ataques
# Out:
#        case_number  year        type             country        activity  \
# 0       2018.06.25  2018     Boating                 usa        Paddling
# 1     2018.06.03.a  2018  Unprovoked              brazil        Swimming
# 2     2018.05.26.b  2018  Unprovoked                 usa         Walking
# 3       2018.05.24  2018    Provoked           australia  Feeding sharks
# 4     2018.05.13.a  2018     Invalid             england         Fishing
# ...            ...   ...         ...                 ...             ...
# 1667       ND.0005  1997  Unprovoked           australia          Diving
# 1668       ND.0004  1997  Unprovoked           australia    Pearl diving
# 1669       ND.0003  1997  Unprovoked                 usa        Swimming
# 1670       ND.0002  1997  Unprovoked              panama             NaN
# 1671       ND.0001  1997  Unprovoked  ceylon (sri lanka)        Swimming
#
#         age          species_      mes fatal sex        especies  edad
# 0        57       White shark      Jun     N   F  Tiburón Blanco    57
# 1        18       Tiger shark      Jun     Y   M   Tiburón tigre    18
# 2        15    Bull shark, 6'      May     N   M    Tiburón toro    15
# 3        32   Grey reef shark      May     N   M    Tiburón Gris    32
# 4        21  Invalid incident      May     N   M     Unspecified    21
# ...     ...               ...      ...   ...  ..             ...   ...
# 1667  24.66               NaN  Unknown     Y   M             NaN     0
# 1668  24.66               NaN  Unknown     Y   M             NaN     0
# 1669  24.66               NaN  Unknown     Y   M             NaN     0
# 1670  24.66               NaN  Unknown     Y   M             NaN     0
# 1671     15               NaN  Unknown     Y   M             NaN    15
#
# [1672 rows x 12 columns]

# %% [markdown]
# 3. Guardad el csv para seguir trabajando con el en los siguientes ejercicios de pair.

# %%
ataques.to_csv("../ficheros/ataques_limpiezaIV.csv")
